# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("amsterdam_weekdays.csv")

# %%
df
# Out:
#       Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0              0   194.033698     Private room        False          True
# 1              1   344.245776     Private room        False          True
# 2              2   264.101422     Private room        False          True
# 3              3   433.529398     Private room        False          True
# 4              4   485.552926     Private room        False          True
# ...          ...          ...              ...          ...           ...
# 1098        1098  2486.115342  Entire home/apt        False         False
# 1099        1099   233.637194     Private room        False          True
# 1100        1100   317.062311     Private room        False          True
# 1101        1101  1812.855904  Entire home/apt        False         False
# 1102        1102   258.008577      Shared room         True         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# ...

# %%
room_type = df['room_type'].astype('category').cat.codes

# %%
df = df.drop('room_type', axis=1)

# %%
'''
Entire home/apt - 0
Private room - 1
Shared room - 2
'''
# Out:
# '\nEntire home/apt - 0\nPrivate room - 1\nShared room - 2\n'

# %%
df['room_type'] = room_type

# %%
df
# Out:
#       Unnamed: 0      realSum  room_shared  room_private  person_capacity  \
# 0              0   194.033698        False          True              2.0
# 1              1   344.245776        False          True              4.0
# 2              2   264.101422        False          True              2.0
# 3              3   433.529398        False          True              4.0
# 4              4   485.552926        False          True              2.0
# ...          ...          ...          ...           ...              ...
# 1098        1098  2486.115342        False         False              2.0
# 1099        1099   233.637194        False          True              2.0
# 1100        1100   317.062311        False          True              2.0
# 1101        1101  1812.855904        False         False              4.0
# 1102        1102   258.008577         True         False              2.0
#
#       host_is_superhost  multi  biz  cleanliness_rating  \
# ...

# %%
room_shared = df['room_shared'].astype('category').cat.codes

# %%
df = df.drop('room_shared', axis=1)

# %%
df['room_shared'] = room_shared

# %%
df
# Out:
#       Unnamed: 0      realSum  room_private  person_capacity  \
# 0              0   194.033698          True              2.0
# 1              1   344.245776          True              4.0
# 2              2   264.101422          True              2.0
# 3              3   433.529398          True              4.0
# 4              4   485.552926          True              2.0
# ...          ...          ...           ...              ...
# 1098        1098  2486.115342         False              2.0
# 1099        1099   233.637194          True              2.0
# 1100        1100   317.062311          True              2.0
# 1101        1101  1812.855904         False              4.0
# 1102        1102   258.008577         False              2.0
#
#       host_is_superhost  multi  biz  cleanliness_rating  \
# 0                 False      1    0                10.0
# 1                 False      0    0                 8.0
# 2                 False      0    1                 9.0
# ...

# %%
room_private = df['room_private'].astype('category').cat.codes

# %%
df = df.drop('room_private', axis=1)

# %%
df['room_private'] = room_shared

# %%
df
# Out:
#       Unnamed: 0      realSum  person_capacity  host_is_superhost  multi  biz  \
# 0              0   194.033698              2.0              False      1    0
# 1              1   344.245776              4.0              False      0    0
# 2              2   264.101422              2.0              False      0    1
# 3              3   433.529398              4.0              False      0    1
# 4              4   485.552926              2.0               True      0    0
# ...          ...          ...              ...                ...    ...  ...
# 1098        1098  2486.115342              2.0              False      0    0
# 1099        1099   233.637194              2.0              False      1    0
# 1100        1100   317.062311              2.0              False      1    0
# 1101        1101  1812.855904              4.0              False      0    0
# 1102        1102   258.008577              2.0              False      0    0
#
# ...

# %%
superhost = df['host_is_superhost'].astype('category').cat.codes

# %%
df = df.drop('host_is_superhost', axis=1)

# %%
df['host_is_superhost'] = superhost

# %%
df
# Out:
#       Unnamed: 0      realSum  person_capacity  multi  biz  \
# 0              0   194.033698              2.0      1    0
# 1              1   344.245776              4.0      0    0
# 2              2   264.101422              2.0      0    1
# 3              3   433.529398              4.0      0    1
# 4              4   485.552926              2.0      0    0
# ...          ...          ...              ...    ...  ...
# 1098        1098  2486.115342              2.0      0    0
# 1099        1099   233.637194              2.0      1    0
# 1100        1100   317.062311              2.0      1    0
# 1101        1101  1812.855904              4.0      0    0
# 1102        1102   258.008577              2.0      0    0
#
#       cleanliness_rating  guest_satisfaction_overall  bedrooms      dist  \
# 0                   10.0                        93.0         1  5.022964
# 1                    8.0                        85.0         1  0.488389
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       Unnamed: 0      realSum  person_capacity  multi  biz  \
# 0              0   194.033698              2.0      1    0
# 1              1   344.245776              4.0      0    0
# 2              2   264.101422              2.0      0    1
# 3              3   433.529398              4.0      0    1
# 4              4   485.552926              2.0      0    0
# ...          ...          ...              ...    ...  ...
# 1098        1098  2486.115342              2.0      0    0
# 1099        1099   233.637194              2.0      1    0
# 1100        1100   317.062311              2.0      1    0
# 1101        1101  1812.855904              4.0      0    0
# 1102        1102   258.008577              2.0      0    0
#
#       cleanliness_rating  guest_satisfaction_overall  bedrooms      dist  \
# 0                   10.0                        93.0         1  5.022964
# 1                    8.0                        85.0         1  0.488389
# ...

# %%
columns_to_check = ['realSum']

# For each column, calculate Q1 (25th percentile) and Q3 (75th percentile) and the IQR
for column in columns_to_check:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Define limits for outliers
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    
    # Filter out outliers
    df = df[(df[column] >= lower_limit) & (df[column] <= upper_limit)]

# %%
df
# Out:
#       Unnamed: 0     realSum  person_capacity  multi  biz  cleanliness_rating  \
# 0              0  194.033698              2.0      1    0                10.0
# 1              1  344.245776              4.0      0    0                 8.0
# 2              2  264.101422              2.0      0    1                 9.0
# 3              3  433.529398              4.0      0    1                 9.0
# 4              4  485.552926              2.0      0    0                10.0
# ...          ...         ...              ...    ...  ...                 ...
# 1096        1096  295.034331              2.0      0    1                 8.0
# 1097        1097  356.197127              4.0      0    0                10.0
# 1099        1099  233.637194              2.0      1    0                10.0
# 1100        1100  317.062311              2.0      1    0                10.0
# 1102        1102  258.008577              2.0      0    0                 8.0
#
# ...

# %%
df = df.drop('room_shared', axis=1)

# %%
df = df.drop('room_private', axis=1)

# %%
df = df.drop('lng', axis=1)

# %%
df = df.drop('lat', axis=1)

# %%
df
# Out:
#       Unnamed: 0     realSum  person_capacity  multi  biz  cleanliness_rating  \
# 0              0  194.033698              2.0      1    0                10.0
# 1              1  344.245776              4.0      0    0                 8.0
# 2              2  264.101422              2.0      0    1                 9.0
# 3              3  433.529398              4.0      0    1                 9.0
# 4              4  485.552926              2.0      0    0                10.0
# ...          ...         ...              ...    ...  ...                 ...
# 1096        1096  295.034331              2.0      0    1                 8.0
# 1097        1097  356.197127              4.0      0    0                10.0
# 1099        1099  233.637194              2.0      1    0                10.0
# 1100        1100  317.062311              2.0      1    0                10.0
# 1102        1102  258.008577              2.0      0    0                 8.0
#
# ...

# %%
corr_matrix = df.corr()

# %%
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
df = df.drop('attr_index', axis=1)

# %%
df = df.drop('rest_index', axis=1)

# %%
df
# Out:
#       Unnamed: 0     realSum  person_capacity  multi  biz  cleanliness_rating  \
# 0              0  194.033698              2.0      1    0                10.0
# 1              1  344.245776              4.0      0    0                 8.0
# 2              2  264.101422              2.0      0    1                 9.0
# 3              3  433.529398              4.0      0    1                 9.0
# 4              4  485.552926              2.0      0    0                10.0
# ...          ...         ...              ...    ...  ...                 ...
# 1096        1096  295.034331              2.0      0    1                 8.0
# 1097        1097  356.197127              4.0      0    0                10.0
# 1099        1099  233.637194              2.0      1    0                10.0
# 1100        1100  317.062311              2.0      1    0                10.0
# 1102        1102  258.008577              2.0      0    0                 8.0
#
# ...

# %%
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
df = df.drop('rest_index_norm', axis=1)

# %%
df = df.drop('attr_index_norm', axis=1)

# %%
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# realSum                       float64
# person_capacity               float64
# multi                           int64
# biz                             int64
# cleanliness_rating            float64
# guest_satisfaction_overall    float64
# bedrooms                        int64
# dist                          float64
# metro_dist                    float64
# room_type                        int8
# host_is_superhost                int8
# dtype: object

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#          realSum  person_capacity  multi  biz  cleanliness_rating  \
# 0     194.033698              2.0      1    0                10.0
# 1     344.245776              4.0      0    0                 8.0
# 2     264.101422              2.0      0    1                 9.0
# 3     433.529398              4.0      0    1                 9.0
# 4     485.552926              2.0      0    0                10.0
# ...          ...              ...    ...  ...                 ...
# 1096  295.034331              2.0      0    1                 8.0
# 1097  356.197127              4.0      0    0                10.0
# 1099  233.637194              2.0      1    0                10.0
# 1100  317.062311              2.0      1    0                10.0
# 1102  258.008577              2.0      0    0                 8.0
#
#       guest_satisfaction_overall  bedrooms      dist  metro_dist  room_type  \
# 0                           93.0         1  5.022964    2.539380          1
# ...

# %%
numerical_columns = df.select_dtypes(include=['int8', 'int64', 'float64']).columns
df[numerical_columns] = df[numerical_columns].astype('float64')

# %%
df.dtypes
# Out:
# realSum                       float64
# person_capacity               float64
# multi                         float64
# biz                           float64
# cleanliness_rating            float64
# guest_satisfaction_overall    float64
# bedrooms                      float64
# dist                          float64
# metro_dist                    float64
# room_type                     float64
# host_is_superhost             float64
# dtype: object
